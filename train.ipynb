# %%
from unsloth import FastLanguageModel, FastModel
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 from unsloth import FastLanguageModel, FastModel
#
# ImportError: cannot import name 'FastLanguageModel' from 'unsloth' (unknown location)

# %%
# !which python
# Out:
# /home/dyh/miniconda3/envs/unsloth_env/bin/python
